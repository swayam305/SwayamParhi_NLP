# %% [markdown]
# <a href="https://colab.research.google.com/github/swayam305/SwayamParhi_NLP/blob/main/Assignment4_Text_Search/Assignment4_J066_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from thefuzz import process, fuzz
import re

def preprocess_name(name):
    """Clean and normalize names for better matching"""
    if pd.isna(name):
        return ""

    # Convert to lowercase
    name = str(name).lower()

    # Remove non-alphanumeric characters except spaces, apostrophes, and hyphens
    name = re.sub(r'[^a-z\'\- ]', '', name)

    # Normalize spaces - replace multiple spaces with single space
    name = re.sub(r' +', ' ', name).strip()

    return name

# Read CSV files using pandas
base_df = pd.read_csv('base_names.csv')
variations_df = pd.read_csv('name_variations.csv')

# Preprocess base names and create a mapping
base_names_mapping = {}
for _, row in base_df.iterrows():
    clean_name = preprocess_name(row['Base_Name'])
    base_names_mapping[clean_name] = row['Base_Name']

# Function to find the best match for a variation
def find_best_match(variation):
    clean_variation = preprocess_name(variation)

    # Use process.extractOne to find the best match
    best_match, score = process.extractOne(
        clean_variation,
        list(base_names_mapping.keys()),
        scorer=fuzz.token_sort_ratio
    )

    if score >= 80:
        return base_names_mapping[best_match], score
    else:
        return "No match found", score

# Apply the matching function to all variations
variations_df[['Matched_Base_Name', 'Confidence_Score']] = variations_df['Variation'].apply(
    lambda x: pd.Series(find_best_match(x))
)

# Display results
print("Matching Results:")
print("=" * 50)
print(variations_df.to_string(index=False))

# Save results to CSV
variations_df.to_csv('name_matches_pandas.csv', index=False)
print(f"\nResults saved to 'name_matches_pandas.csv'")

# Optional: Show summary statistics
print(f"\nSummary Statistics:")
print(f"Total variations: {len(variations_df)}")
matched_count = (variations_df['Matched_Base_Name'] != "No match found").sum()
print(f"Successfully matched: {matched_count} ({matched_count/len(variations_df)*100:.1f}%)")

# Show matches with confidence scores
print(f"\nDetailed matches with confidence scores:")
for _, row in variations_df.iterrows():
    status = "✓" if row['Matched_Base_Name'] != "No match found" else "✗"
    print(f"{status} {row['Variation']} -> {row['Matched_Base_Name']} ({row['Confidence_Score']})")
# Out:
# Matching Results:
# ==================================================
#          Variation Matches_With_Base_Name Matched_Base_Name  Confidence_Score
#       Thomas  King            Thomas King       Thomas King               100
#         ThomasKing            Thomas King    No match found                57
#       Maria Garcia           Maria Garcia      Maria Garcia               100
#          MaryLewis             Mary Lewis    No match found                53
#           Nancy W.           Nancy Wright    No match found                74
#       Dani3l Scott           Daniel Scott      Daniel Scott                96
#        JOHN  smith             John Smith        John Smith               100
#      linda johnson          Linda Johnson     Linda Johnson               100
#       N@ncy Wright           Nancy Wright      Nancy Wright                96
#      William Davis          William Davis     William Davis               100
#       Susan  Clark            Susan Clark       Susan Clark               100
#         SusanClark            Susan Clark    No match found                48
#    Jennifer- Brown         Jennifer Brown    Jennifer Brown               100
#   Michael O'Connor       Michael O'Connor  Michael O'Connor               100
#    Rodriguez James        James Rodriguez   James Rodriguez               100
#   Elizabeth Wil5on       Elizabeth Wilson  Elizabeth Wilson                97
#        Hill Sandra            Sandra Hill       Sandra Hill               100
#        THOMAS KING            Thomas King       Thomas King               100
#  Christoph3r Green      Christopher Green Christopher Green                97
#   James- Rodriguez        James Rodriguez   James Rodriguez               100
#          Robert L.             Robert Lee        Robert Lee                89
#            Rob Lee             Robert Lee        Robert Lee                82
#          Kar Young            Karen Young       Karen Young                90
#   elizabeth wilson       Elizabeth Wilson  Elizabeth Wilson               100
#           David M.         David Martinez    No match found                67
#      Daniel  Scott           Daniel Scott      Daniel Scott               100
#     D@vid Martinez         David Martinez    David Martinez                96
#      Jam Rodriguez        James Rodriguez   James Rodriguez                93
#       Karen  Young            Karen Young       Karen Young               100
#       WilliamDavis          William Davis    No match found                56
#        John- Smith             John Smith        John Smith               100
#        John  Smith             John Smith        John Smith               100
#     David Martinez         David Martinez    David Martinez               100
#        Young Karen            Karen Young       Karen Young               100
#      Jessica Adams          Jessica Adams     Jessica Adams               100
#  Michael  O'Connor       Michael O'Connor  Michael O'Connor               100
#         paul allen             Paul Allen        Paul Allen               100
#    JENNIFER  brown         Jennifer Brown    Jennifer Brown               100
#    Jennifer- Brown         Jennifer Brown    Jennifer Brown               100
#      Daniel- Scott           Daniel Scott      Daniel Scott               100
#           David M.         David Martinez    No match found                67
#        Paul Allen.             Paul Allen        Paul Allen               100
#        Paul  Allen             Paul Allen        Paul Allen               100
#
# Results saved to 'name_matches_pandas.csv'
#
# Summary Statistics:
# Total variations: 100
# Successfully matched: 90 (90.0%)
#
# Detailed matches with confidence scores:
# ✓ Thomas  King -> Thomas King (100)
# ✗ ThomasKing -> No match found (57)
# ✓ Maria Garcia -> Maria Garcia (100)
# ✗ MaryLewis -> No match found (53)
# ✗ Nancy W. -> No match found (74)
# ✓ Dani3l Scott -> Daniel Scott (96)
# ✓ JOHN  smith -> John Smith (100)
# ✓ linda johnson -> Linda Johnson (100)
# ✓ N@ncy Wright -> Nancy Wright (96)
# ✓ William Davis -> William Davis (100)
# ✓ Susan  Clark -> Susan Clark (100)
# ✗ SusanClark -> No match found (48)
# ✓ Jennifer- Brown -> Jennifer Brown (100)
# ✓ Michael O'Connor -> Michael O'Connor (100)
# ✓ Rodriguez James -> James Rodriguez (100)
# ✓ Elizabeth Wil5on -> Elizabeth Wilson (97)
# ✓ Hill Sandra -> Sandra Hill (100)
# ✓ THOMAS KING -> Thomas King (100)
# ✓ Christoph3r Green -> Christopher Green (97)
# ✓ Wi11iam Davis -> William Davis (92)
# ✓ linda johnson -> Linda Johnson (100)
# ✗ John tihSm -> No match found (70)
# ✓ Nancy Wright -> Nancy Wright (100)
# ✓ Robert L. -> Robert Lee (89)
# ✓ Christopher Green -> Christopher Green (100)
# ✓ Thomas King -> Thomas King (100)
# ✓ Rob3rt Lee -> Robert Lee (95)
# ✓ Kar3n Young -> Karen Young (95)
# ✓ DAVID  martinez -> David Martinez (100)
# ✓ N@ncy Wright -> Nancy Wright (96)
# ✓ Elizab3th Wilson -> Elizabeth Wilson (97)
# ✓ Maria  Garcia -> Maria Garcia (100)
# ✓ Robert  Lee -> Robert Lee (100)
# ✓ Nancy Wright -> Nancy Wright (100)
# ✗ Maria G. -> No match found (74)
# ✓ S@ndr@ Hill -> Sandra Hill (90)
# ✓ Mary Lew -> Mary Lewis (89)
# ✓ Jessic@ Adams -> Jessica Adams (96)
# ✓ William  Davis -> William Davis (100)
# ✓ Maria  Garcia -> Maria Garcia (100)
# ✓ Jennifer Brown -> Jennifer Brown (100)
# ✓ jennifer brown -> Jennifer Brown (100)
# ✓ Mary  Lewis -> Mary Lewis (100)
# ✓ Susan Clark -> Susan Clark (100)
# ✓ Michael  O'Connor -> Michael O'Connor (100)
# ✓ Clark Susan -> Susan Clark (100)
# ✓ Sandra Hill. -> Sandra Hill (100)
# ✓ Mich@el O'Connor -> Michael O'Connor (97)
# ✓ Christopher  Green -> Christopher Green (100)
# ✓ Daniel Scott -> Daniel Scott (100)
# ✓ J. Smith -> John Smith (82)
# ✓ Jessica  Adams -> Jessica Adams (100)
# ✓ Mary Lew -> Mary Lewis (89)
# ✓ Elizab3th Wilson -> Elizabeth Wilson (97)
# ✓ sandra hill -> Sandra Hill (100)
# ✓ linda johnson -> Linda Johnson (100)
# ✓ Adams Jessica -> Jessica Adams (100)
# ✓ Daniel  Scott -> Daniel Scott (100)
# ✓ PAUL ALLEN -> Paul Allen (100)
# ✓ Paul Allen. -> Paul Allen (100)
# ✓ Susan Clark -> Susan Clark (100)
# ✓ JamesRodriguez -> James Rodriguez (97)
# ✓ Thomas King -> Thomas King (100)
# ✓ Linda  Johnson -> Linda Johnson (100)
# ✓ elizabeth wilson -> Elizabeth Wilson (100)
# ✓ Karen Young -> Karen Young (100)
# ✓ MICHAEL O'CONNOR -> Michael O'Connor (100)
# ✓ Linda Johnson -> Linda Johnson (100)
# ✓ Maria  Garcia -> Maria Garcia (100)
# ✓ Sandra Hil -> Sandra Hill (95)
# ✗ J. Adams -> No match found (70)
# ✓ Lewis Mary -> Mary Lewis (100)
# ✓ Christopher  Green -> Christopher Green (100)
# ✓ Rodriguez James -> James Rodriguez (100)
# ✓ christopher green -> Christopher Green (100)
# ✓ William  Davis -> William Davis (100)
# ✓ James- Rodriguez -> James Rodriguez (100)
# ✓ Robert L. -> Robert Lee (89)
# ✓ Rob Lee -> Robert Lee (82)
# ✓ Kar Young -> Karen Young (90)
# ✓ elizabeth wilson -> Elizabeth Wilson (100)
# ✗ David M. -> No match found (67)
# ✓ Daniel  Scott -> Daniel Scott (100)
# ✓ D@vid Martinez -> David Martinez (96)
# ✓ Jam Rodriguez -> James Rodriguez (93)
# ✓ Karen  Young -> Karen Young (100)
# ✗ WilliamDavis -> No match found (56)
# ✓ John- Smith -> John Smith (100)
# ✓ John  Smith -> John Smith (100)
# ✓ David Martinez -> David Martinez (100)
# ✓ Young Karen -> Karen Young (100)
# ✓ Jessica Adams -> Jessica Adams (100)
# ✓ Michael  O'Connor -> Michael O'Connor (100)
# ✓ paul allen -> Paul Allen (100)
# ✓ JENNIFER  brown -> Jennifer Brown (100)
# ✓ Jennifer- Brown -> Jennifer Brown (100)
# ✓ Daniel- Scott -> Daniel Scott (100)
# ✗ David M. -> No match found (67)
# ✓ Paul Allen. -> Paul Allen (100)
# ✓ Paul  Allen -> Paul Allen (100)
